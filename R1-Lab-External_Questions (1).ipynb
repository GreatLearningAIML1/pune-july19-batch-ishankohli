# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import numpy as np
import pandas as pd
iris = pd.read_csv('C:\\Ishan\\Greatlearning\\Labs\\1. 7 july\\Iris.csv')
iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
iris.dtypes
# Out:
# Sepal Length (in cm)    float64
# Sepal Width in (cm)     float64
# Petal length (in cm)    float64
# Petal width (in cm)     float64
# Class                    object
# dtype: object

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
iris.head(10)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa
# 5                  0.4  Iris-setosa
# 6                  0.3  Iris-setosa
# 7                  0.2  Iris-setosa
# 8                  0.2  Iris-setosa
# 9                  0.1  Iris-setosa

# %%
iris.tail(10)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica

# %% [markdown]
# ### Find the shape of the dataset

# %%
iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
iris["my_indx"] = iris['Sepal Length (in cm)']

# %%
iris.set_index('my_indx',inplace=False).head()
# Out:
#          Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# my_indx
# 5.1                       5.1                  3.5                   1.4
# 4.9                       4.9                  3.0                   1.4
# 4.7                       4.7                  3.2                   1.3
# 4.6                       4.6                  3.1                   1.5
# 5.0                       5.0                  3.6                   1.4
#
#          Petal width (in cm)        Class
# my_indx
# 5.1                      0.2  Iris-setosa
# 4.9                      0.2  Iris-setosa
# 4.7                      0.2  Iris-setosa
# 4.6                      0.2  Iris-setosa
# 5.0                      0.2  Iris-setosa

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
iris.iloc[:,3]
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
# 5      0.4
# 6      0.3
# 7      0.2
# 8      0.2
# 9      0.1
# 10     0.2
# 11     0.2
# 12     0.1
# 13     0.1
# 14     0.2
# 15     0.4
# 16     0.4
# 17     0.3
# 18     0.3
# 19     0.3
# 20     0.2
# 21     0.4
# 22     0.2
# 23     0.5
# 24     0.2
# 25     0.2
# 26     0.4
# 27     0.2
# 28     0.2
# 29     0.2
#       ...
# 120    2.3
# 121    2.0
# 122    2.0
# 123    1.8
# 124    2.1
# 125    1.8
# 126    1.8
# 127    1.8
# 128    2.1
# 129    1.6
# 130    1.9
# 131    2.0
# 132    2.2
# 133    1.5
# 134    1.4
# 135    2.3
# 136    2.4
# 137    1.8
# 138    1.8
# 139    2.1
# 140    2.4
# 141    2.3
# 142    1.9
# 143    2.3
# 144    2.5
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: Petal width (in cm), Length: 150, dtype: float64

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
iris.iloc[0:10,0:2]
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)
# 0                   5.1                  3.5
# 1                   4.9                  3.0
# 2                   4.7                  3.2
# 3                   4.6                  3.1
# 4                   5.0                  3.6
# 5                   5.4                  3.9
# 6                   4.6                  3.4
# 7                   5.0                  3.4
# 8                   4.4                  2.9
# 9                   4.9                  3.1

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
##iris[iris['Class']=="Iris-setosa"]
iris.loc[iris['Class']=="Iris-setosa"]
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                    5.1                  3.5                   1.4
# 1                    4.9                  3.0                   1.4
# 2                    4.7                  3.2                   1.3
# 3                    4.6                  3.1                   1.5
# 4                    5.0                  3.6                   1.4
# 5                    5.4                  3.9                   1.7
# 6                    4.6                  3.4                   1.4
# 7                    5.0                  3.4                   1.5
# 8                    4.4                  2.9                   1.4
# 9                    4.9                  3.1                   1.5
# 10                   5.4                  3.7                   1.5
# 11                   4.8                  3.4                   1.6
# 12                   4.8                  3.0                   1.4
# 13                   4.3                  3.0                   1.1
# 14                   5.8                  4.0                   1.2
# 15                   5.7                  4.4                   1.5
# 16                   5.4                  3.9                   1.3
# 17                   5.1                  3.5                   1.4
# 18                   5.7                  3.8                   1.7
# 19                   5.1                  3.8                   1.5
# 20                   5.4                  3.4                   1.7
# 21                   5.1                  3.7                   1.5
# 22                   4.6                  3.6                   1.0
# 23                   5.1                  3.3                   1.7
# 24                   4.8                  3.4                   1.9
# 25                   5.0                  3.0                   1.6
# 26                   5.0                  3.4                   1.6
# 27                   5.2                  3.5                   1.5
# 28                   5.2                  3.4                   1.4
# 29                   4.7                  3.2                   1.6
# 30                   4.8                  3.1                   1.6
# 31                   5.4                  3.4                   1.5
# 32                   5.2                  4.1                   1.5
# 33                   5.5                  4.2                   1.4
# 34                   4.9                  3.1                   1.5
# 35                   5.0                  3.2                   1.2
# 36                   5.5                  3.5                   1.3
# 37                   4.9                  3.1                   1.5
# 38                   4.4                  3.0                   1.3
# 39                   5.1                  3.4                   1.5
# 40                   5.0                  3.5                   1.3
# 41                   4.5                  2.3                   1.3
# 42                   4.4                  3.2                   1.3
# 43                   5.0                  3.5                   1.6
# 44                   5.1                  3.8                   1.9
# 45                   4.8                  3.0                   1.4
# 46                   5.1                  3.8                   1.6
# 47                   4.6                  3.2                   1.4
# 48                   5.3                  3.7                   1.5
# 49                   5.0                  3.3                   1.4
#
#     Petal width (in cm)        Class  my_indx
# 0                   0.2  Iris-setosa      5.1
# 1                   0.2  Iris-setosa      4.9
# 2                   0.2  Iris-setosa      4.7
# 3                   0.2  Iris-setosa      4.6
# 4                   0.2  Iris-setosa      5.0
# 5                   0.4  Iris-setosa      5.4
# 6                   0.3  Iris-setosa      4.6
# 7                   0.2  Iris-setosa      5.0
# 8                   0.2  Iris-setosa      4.4
# 9                   0.1  Iris-setosa      4.9
# 10                  0.2  Iris-setosa      5.4
# 11                  0.2  Iris-setosa      4.8
# 12                  0.1  Iris-setosa      4.8
# 13                  0.1  Iris-setosa      4.3
# 14                  0.2  Iris-setosa      5.8
# 15                  0.4  Iris-setosa      5.7
# 16                  0.4  Iris-setosa      5.4
# 17                  0.3  Iris-setosa      5.1
# 18                  0.3  Iris-setosa      5.7
# 19                  0.3  Iris-setosa      5.1
# 20                  0.2  Iris-setosa      5.4
# 21                  0.4  Iris-setosa      5.1
# 22                  0.2  Iris-setosa      4.6
# 23                  0.5  Iris-setosa      5.1
# 24                  0.2  Iris-setosa      4.8
# 25                  0.2  Iris-setosa      5.0
# 26                  0.4  Iris-setosa      5.0
# 27                  0.2  Iris-setosa      5.2
# 28                  0.2  Iris-setosa      5.2
# 29                  0.2  Iris-setosa      4.7
# 30                  0.2  Iris-setosa      4.8
# 31                  0.4  Iris-setosa      5.4
# 32                  0.1  Iris-setosa      5.2
# 33                  0.2  Iris-setosa      5.5
# 34                  0.1  Iris-setosa      4.9
# 35                  0.2  Iris-setosa      5.0
# 36                  0.2  Iris-setosa      5.5
# 37                  0.1  Iris-setosa      4.9
# 38                  0.2  Iris-setosa      4.4
# 39                  0.2  Iris-setosa      5.1
# 40                  0.3  Iris-setosa      5.0
# 41                  0.3  Iris-setosa      4.5
# 42                  0.2  Iris-setosa      4.4
# 43                  0.6  Iris-setosa      5.0
# 44                  0.4  Iris-setosa      5.1
# 45                  0.3  Iris-setosa      4.8
# 46                  0.2  Iris-setosa      5.1
# 47                  0.2  Iris-setosa      4.6
# 48                  0.2  Iris-setosa      5.3
# 49                  0.2  Iris-setosa      5.0

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
iris['SepalExtra'] = iris['Sepal Length (in cm)'] * iris['Sepal Width in (cm)']

# %%
iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class  my_indx  SepalExtra
# 0                  0.2  Iris-setosa      5.1       17.85
# 1                  0.2  Iris-setosa      4.9       14.70
# 2                  0.2  Iris-setosa      4.7       15.04
# 3                  0.2  Iris-setosa      4.6       14.26
# 4                  0.2  Iris-setosa      5.0       18.00

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
iris.groupby("Class").agg(["mean","var"])
# Out:
#                 Sepal Length (in cm)           Sepal Width in (cm)            \
#                                 mean       var                mean       var
# Class
# Iris-setosa                    5.006  0.124249               3.418  0.145180
# Iris-versicolor                5.936  0.266433               2.770  0.098469
# Iris-virginica                 6.588  0.404343               2.974  0.104004
#
#                 Petal length (in cm)           Petal width (in cm)            \
#                                 mean       var                mean       var
# Class
# Iris-setosa                    1.464  0.030106               0.244  0.011494
# Iris-versicolor                4.260  0.220816               1.326  0.039106
# Iris-virginica                 5.552  0.304588               2.026  0.075433
#
#                 my_indx           SepalExtra
#                    mean       var       mean        var
# Class
# Iris-setosa       5.006  0.124249    17.2088   8.688864
# Iris-versicolor   5.936  0.266433    16.5262   8.219012
# Iris-virginica    6.588  0.404343    19.6846  11.963180

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def input_num(num1,num2):
    print(num1, num2)
input_num(iris.iloc[5,0],iris.iloc[5,1])
# Out:
# 5.4 3.9

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
for key, value in iris.iteritems(): 
    if(value.dtype == 'float64'):
        Range=max(value)-min(value)
        print(key,Range)
# Out:
# Sepal Length (in cm) 3.6000000000000005
# Sepal Width in (cm) 2.4000000000000004
# Petal length (in cm) 5.9
# Petal width (in cm) 2.4
# my_indx 3.6000000000000005
# SepalExtra 20.02

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
iris.sort_values(by=['Petal width (in cm)'],ascending=False).head(5)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 100                   6.3                  3.3                   6.0
# 109                   7.2                  3.6                   6.1
# 144                   6.7                  3.3                   5.7
# 114                   5.8                  2.8                   5.1
# 140                   6.7                  3.1                   5.6
#
#      Petal width (in cm)           Class  my_indx  SepalExtra
# 100                  2.5  Iris-virginica      6.3       20.79
# 109                  2.5  Iris-virginica      7.2       25.92
# 144                  2.5  Iris-virginica      6.7       22.11
# 114                  2.4  Iris-virginica      5.8       16.24
# 140                  2.4  Iris-virginica      6.7       20.77

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
iris.drop('SepalExtra',axis=1,inplace=True)

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
IrisSubset=iris.iloc[:,0:3].head(10)
IrisSubset.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
HR=pd.read_csv('C:\\Ishan\\Greatlearning\\Labs\\1. 7 july\\HR_external.txt', sep='\t')
HR.head()
# Out:
#   Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0        Ind1       Yes   41               1       1102           1
# 1        Ind2        No   49               2        279           2
# 2        Ind3       Yes   37               1       1373           2
# 3        Ind4        No   33               2       1392           2
# 4        Ind5        No   27               1        591           2
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 0                 1          2               1              1  ...
# 1                 8          1               1              1  ...
# 2                 2          2               6              1  ...
# 3                 3          4               1              1  ...
# 4                 2          1               2              1  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# 1                         4             80                 1
# 2                         2             80                 0
# 3                         3             80                 0
# 4                         4             80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 3                  8                      3                3               8
# 4                  6                      3                3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
HR.shape
# Out:
# (1470, 35)

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
HR.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
HR.iloc[:,3:11]
# Out:
#       BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0                  1       1102           1                 1          2
# 1                  2        279           2                 8          1
# 2                  1       1373           2                 2          2
# 3                  2       1392           2                 3          4
# 4                  1        591           2                 2          1
# 5                  2       1005           2                 2          2
# 6                  1       1324           2                 3          3
# 7                  1       1358           2                24          1
# 8                  2        216           2                23          3
# 9                  1       1299           2                27          3
# 10                 1        809           2                16          3
# 11                 1        153           2                15          2
# 12                 1        670           2                26          1
# 13                 1       1346           2                19          2
# 14                 1        103           2                24          3
# 15                 1       1389           2                21          4
# 16                 1        334           2                 5          2
# 17                 3       1123           2                16          2
# 18                 1       1219           1                 2          4
# 19                 1        371           2                 2          3
# 20                 3        673           2                11          2
# 21                 1       1218           1                 9          4
# 22                 1        419           2                 7          4
# 23                 1        391           2                15          2
# 24                 1        699           2                 6          1
# 25                 1       1282           2                 5          3
# 26                 2       1125           2                16          1
# 27                 1        691           1                 8          4
# 28                 1        477           2                 7          4
# 29                 1        705           1                 2          4
# ...              ...        ...         ...               ...        ...
# 1440               2        688           2                 4          2
# 1441               3        667           2                 1          4
# 1442               1       1092           2                 1          4
# 1443               1        300           2                 2          3
# 1444               1        310           2                 7          2
# 1445               1        582           2                28          4
# 1446               1        704           1                28          3
# 1447               3        301           1                15          4
# 1448               1        930           1                 3          3
# 1449               1        529           2                 2          3
# 1450               1       1146           3                26          4
# 1451               1        345           1                10          2
# 1452               2        878           1                 1          4
# 1453               1       1120           1                11          4
# 1454               1        374           1                20          3
# 1455               1       1322           2                 2          4
# 1456               2       1199           2                18          4
# 1457               1       1194           2                 2          4
# 1458               1        287           2                 1          4
# 1459               1       1378           2                13          2
# 1460               1        468           2                28          4
# 1461               1        410           1                28          3
# 1462               1        722           1                24          1
# 1463               3        325           2                 5          3
# 1464               1       1167           1                 5          3
# 1465               2        884           2                23          2
# 1466               1        613           2                 6          1
# 1467               1        155           2                 4          3
# 1468               2       1023           1                 2          3
# 1469               1        628           2                 8          3
#
#       EducationField  EmployeeCount  EmployeeNumber
# 0                  1              1               1
# 1                  1              1               2
# 2                  6              1               4
# 3                  1              1               5
# 4                  2              1               7
# 5                  1              1               8
# 6                  2              1              10
# 7                  1              1              11
# 8                  1              1              12
# 9                  2              1              13
# 10                 2              1              14
# 11                 1              1              15
# 12                 1              1              16
# 13                 2              1              18
# 14                 1              1              19
# 15                 1              1              20
# 16                 1              1              21
# 17                 2              1              22
# 18                 1              1              23
# 19                 1              1              24
# 20                 6              1              26
# 21                 1              1              27
# 22                 1              1              28
# 23                 1              1              30
# 24                 2              1              31
# 25                 6              1              32
# 26                 1              1              33
# 27                 3              1              35
# 28                 2              1              36
# 29                 3              1              38
# ...              ...            ...             ...
# 1440               1              1            2025
# 1441               1              1            2026
# 1442               2              1            2027
# 1443               1              1            2031
# 1444               4              1            2032
# 1445               1              1            2034
# 1446               3              1            2035
# 1447               3              1            2036
# 1448               1              1            2037
# 1449               4              1            2038
# 1450               1              1            2040
# 1451               1              1            2041
# 1452               1              1            2044
# 1453               3              1            2045
# 1454               1              1            2046
# 1455               1              1            2048
# 1456               1              1            2049
# 1457               2              1            2051
# 1458               1              1            2052
# 1459               6              1            2053
# 1460               2              1            2054
# 1461               3              1            2055
# 1462               3              1            2056
# 1463               2              1            2057
# 1464               6              1            2060
# 1465               2              1            2061
# 1466               2              1            2062
# 1467               1              1            2064
# 1468               2              1            2065
# 1469               2              1            2068
#
# [1470 rows x 8 columns]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
HR['Gender'].head()
# Out:
# 0    2
# 1    1
# 2    1
# 3    2
# 4    1
# Name: Gender, dtype: int64

# %%
HR['Gender'].value_counts()
# Out:
# 1    882
# 2    588
# Name: Gender, dtype: int64

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
Q3=HR['Age'].quantile(0.75)
Q1=HR['Age'].quantile(0.25)
IQR=Q3-Q1
print(IQR)
# Out:
# 13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
print('Mean ',HR['DailyRate'].mean())
print('Median ',HR['DailyRate'].median())
print('variance ',HR['DailyRate'].var())
# Out:
# Mean  802.4857142857143
# Median  802.0
# variance  162819.59373723628

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x='Attrition',data=HR)

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
sns.distplot(HR["TotalWorkingYears"], kde=True)
